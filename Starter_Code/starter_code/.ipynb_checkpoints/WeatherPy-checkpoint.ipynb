# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities
#
# https://openweathermap.org/current

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import os

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

#print(cities)
# Out:
# Number of cities in the list: 632

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
    # Create endpoint URL with each city
    # city_url = f'{url}lat={lat_lng[0]}&lon={lat_lng[1]}&appid={weather_api_key}'
    city = city.replace(" ", "+")
    city_url = f'{url}{city}&appid={weather_api_key}&units=metric'
    city = city.replace("+", " ")
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | guerrero negro
# Processing Record 3 of Set 1 | sile
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | nguigmi
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | papatowai
# Processing Record 8 of Set 1 | port mathurin
# Processing Record 9 of Set 1 | jinchang
# Processing Record 10 of Set 1 | leava
# Processing Record 11 of Set 1 | concordia
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | ar rutbah
# Processing Record 14 of Set 1 | mezhdurechenskiy
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | olonkinbyen
# Processing Record 17 of Set 1 | najran
# Processing Record 18 of Set 1 | sweet home
# Processing Record 19 of Set 1 | badger
# Processing Record 20 of Set 1 | korsakov
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | tierra colorada
# Processing Record 23 of Set 1 | pemangkat
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | qaqortoq
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | bukama
# Processing Record 29 of Set 1 | olenino
# Processing Record 30 of Set 1 | udachny
# Processing Record 31 of Set 1 | balcarce
# Processing Record 32 of Set 1 | invercargill
# Processing Record 33 of Set 1 | blackmans bay
# Processing Record 34 of Set 1 | tuy hoa
# Processing Record 35 of Set 1 | waitangi
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | stanley
# Processing Record 38 of Set 1 | claremont
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | bonnyville
# Processing Record 41 of Set 1 | belmonte
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | edinburgh of the seven seas
# Processing Record 44 of Set 1 | kuala terengganu
# Processing Record 45 of Set 1 | alice springs
# Processing Record 46 of Set 1 | iskateley
# Processing Record 47 of Set 1 | nar'yan-mar
# Processing Record 48 of Set 1 | vorgashor
# Processing Record 49 of Set 1 | san andros
# City not found. Skipping...
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | winkler
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 5 of Set 2 | san antonio de pale
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | villaviciosa
# Processing Record 8 of Set 2 | kiama
# Processing Record 9 of Set 2 | ust-nera
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | burlington
# Processing Record 12 of Set 2 | ivnya
# Processing Record 13 of Set 2 | klyuchi
# Processing Record 14 of Set 2 | bunia
# Processing Record 15 of Set 2 | remire-montjoly
# Processing Record 16 of Set 2 | formosa do rio preto
# Processing Record 17 of Set 2 | mountain home
# Processing Record 18 of Set 2 | keflavik
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | mount gambier
# Processing Record 21 of Set 2 | marka
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | dudinka
# Processing Record 24 of Set 2 | west island
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | flying fish cove
# Processing Record 27 of Set 2 | shache
# Processing Record 28 of Set 2 | aasiaat
# Processing Record 29 of Set 2 | susuman
# Processing Record 30 of Set 2 | tazacorte
# Processing Record 31 of Set 2 | moree
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | wailua homesteads
# Processing Record 34 of Set 2 | yaring
# Processing Record 35 of Set 2 | tura
# Processing Record 36 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 2 | kawalu
# Processing Record 38 of Set 2 | flin flon
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | martinsburg
# Processing Record 41 of Set 2 | taoudenni
# Processing Record 42 of Set 2 | gbadolite
# Processing Record 43 of Set 2 | kyiv
# Processing Record 44 of Set 2 | muroto-misakicho
# Processing Record 45 of Set 2 | kollo
# Processing Record 46 of Set 2 | anadyr
# Processing Record 47 of Set 2 | farah
# Processing Record 48 of Set 2 | mariehamn
# Processing Record 49 of Set 2 | turaiyur
# Processing Record 0 of Set 3 | jamestown
# Processing Record 1 of Set 3 | whitehorse
# Processing Record 2 of Set 3 | veraval
# Processing Record 3 of Set 3 | howard springs
# Processing Record 4 of Set 3 | juan griego
# Processing Record 5 of Set 3 | kodinsk
# Processing Record 6 of Set 3 | sandnessjoen
# Processing Record 7 of Set 3 | la libertad
# Processing Record 8 of Set 3 | trincomalee
# Processing Record 9 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 10 of Set 3 | mount pearl
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | agat village
# Processing Record 14 of Set 3 | fisterra
# Processing Record 15 of Set 3 | acapulco de juarez
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | sarangani
# Processing Record 18 of Set 3 | karachi
# Processing Record 19 of Set 3 | launceston
# Processing Record 20 of Set 3 | bastrop
# Processing Record 21 of Set 3 | st. john's
# Processing Record 22 of Set 3 | roven'ky
# Processing Record 23 of Set 3 | holualoa
# Processing Record 24 of Set 3 | sola
# Processing Record 25 of Set 3 | khedbrahma
# Processing Record 26 of Set 3 | taroa
# Processing Record 27 of Set 3 | guisa
# Processing Record 28 of Set 3 | abong mbang
# Processing Record 29 of Set 3 | barcelos
# Processing Record 30 of Set 3 | oriximina
# Processing Record 31 of Set 3 | pekan
# Processing Record 32 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 3 | alaghsas
# Processing Record 34 of Set 3 | livingstone
# Processing Record 35 of Set 3 | tabou
# Processing Record 36 of Set 3 | nabire
# Processing Record 37 of Set 3 | santiago de cao
# Processing Record 38 of Set 3 | karbala
# Processing Record 39 of Set 3 | dalandzadgad
# Processing Record 40 of Set 3 | navirai
# Processing Record 41 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | uturoa
# Processing Record 44 of Set 3 | zykovo
# Processing Record 45 of Set 3 | sao joao da ponte
# Processing Record 46 of Set 3 | northam
# Processing Record 47 of Set 3 | maintirano
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | san luis
# Processing Record 0 of Set 4 | solleftea
# Processing Record 1 of Set 4 | kone
# Processing Record 2 of Set 4 | isafjordur
# Processing Record 3 of Set 4 | bel ombre
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | margaret river
# Processing Record 6 of Set 4 | kulhudhuffushi
# Processing Record 7 of Set 4 | utrik
# Processing Record 8 of Set 4 | sanchursk
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | gorontalo
# Processing Record 11 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 4 | hawaiian paradise park
# Processing Record 13 of Set 4 | lerwick
# Processing Record 14 of Set 4 | moranbah
# Processing Record 15 of Set 4 | juneau
# Processing Record 16 of Set 4 | talakan
# Processing Record 17 of Set 4 | lander
# Processing Record 18 of Set 4 | opuwo
# Processing Record 19 of Set 4 | saipan
# Processing Record 20 of Set 4 | punta arenas
# Processing Record 21 of Set 4 | torghay
# Processing Record 22 of Set 4 | kapuskasing
# Processing Record 23 of Set 4 | mae hong son
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | camacupa
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | al jawf
# Processing Record 29 of Set 4 | ruteng
# Processing Record 30 of Set 4 | salihorsk
# Processing Record 31 of Set 4 | kuta
# Processing Record 32 of Set 4 | kabwe
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | arkalyk
# Processing Record 36 of Set 4 | morehead city
# Processing Record 37 of Set 4 | salinas
# Processing Record 38 of Set 4 | kuna
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | hadibu
# Processing Record 42 of Set 4 | faya-largeau
# Processing Record 43 of Set 4 | ulanhot
# Processing Record 44 of Set 4 | sanghar
# Processing Record 45 of Set 4 | san luis de la loma
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | onguday
# Processing Record 48 of Set 4 | san pedro
# Processing Record 49 of Set 4 | linkou
# Processing Record 0 of Set 5 | agadez
# Processing Record 1 of Set 5 | horta
# Processing Record 2 of Set 5 | new norfolk
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | afaahiti
# Processing Record 5 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 6 of Set 5 | kuytun
# Processing Record 7 of Set 5 | alappuzha
# Processing Record 8 of Set 5 | shubarshi
# Processing Record 9 of Set 5 | voi
# Processing Record 10 of Set 5 | kanniyakumari
# Processing Record 11 of Set 5 | taltal
# Processing Record 12 of Set 5 | buritizeiro
# Processing Record 13 of Set 5 | isangel
# Processing Record 14 of Set 5 | lucerne valley
# Processing Record 15 of Set 5 | as saffaniyah
# Processing Record 16 of Set 5 | pluzine
# City not found. Skipping...
# Processing Record 17 of Set 5 | piacabucu
# Processing Record 18 of Set 5 | roosevelt
# Processing Record 19 of Set 5 | ulladulla
# Processing Record 20 of Set 5 | thunder bay
# Processing Record 21 of Set 5 | nema
# Processing Record 22 of Set 5 | ta`u
# Processing Record 23 of Set 5 | hyesan
# Processing Record 24 of Set 5 | verkhnevilyuysk
# Processing Record 25 of Set 5 | labytnangi
# Processing Record 26 of Set 5 | barra de santo antonio
# Processing Record 27 of Set 5 | punta del este
# Processing Record 28 of Set 5 | port isabel
# Processing Record 29 of Set 5 | kavaratti
# Processing Record 30 of Set 5 | kovdor
# Processing Record 31 of Set 5 | le port
# Processing Record 32 of Set 5 | lihue
# Processing Record 33 of Set 5 | banfora
# Processing Record 34 of Set 5 | shenjiamen
# Processing Record 35 of Set 5 | wajir
# Processing Record 36 of Set 5 | fort st. john
# Processing Record 37 of Set 5 | boukadir
# Processing Record 38 of Set 5 | las heras
# Processing Record 39 of Set 5 | jacmel
# Processing Record 40 of Set 5 | college
# Processing Record 41 of Set 5 | gadzhiyevo
# Processing Record 42 of Set 5 | itapuranga
# Processing Record 43 of Set 5 | chernyshevskiy
# Processing Record 44 of Set 5 | cadale
# Processing Record 45 of Set 5 | lesneven
# Processing Record 46 of Set 5 | svetlyy
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | rada tilly
# Processing Record 49 of Set 5 | saldanha
# Processing Record 0 of Set 6 | igarka
# Processing Record 1 of Set 6 | acajutla
# Processing Record 2 of Set 6 | dolores
# Processing Record 3 of Set 6 | tralee
# Processing Record 4 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 6 | kudahuvadhoo
# Processing Record 6 of Set 6 | yarkovo
# Processing Record 7 of Set 6 | sal rei
# Processing Record 8 of Set 6 | tolanaro
# Processing Record 9 of Set 6 | kristiansund
# Processing Record 10 of Set 6 | umea
# Processing Record 11 of Set 6 | bali chak
# Processing Record 12 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | rongelap
# Processing Record 15 of Set 6 | leninskoye
# Processing Record 16 of Set 6 | mhamid
# Processing Record 17 of Set 6 | yemetsk
# Processing Record 18 of Set 6 | aykhal
# Processing Record 19 of Set 6 | newman
# Processing Record 20 of Set 6 | urzhar
# Processing Record 21 of Set 6 | haiku-pauwela
# Processing Record 22 of Set 6 | prineville
# Processing Record 23 of Set 6 | constantia
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | yoko
# Processing Record 26 of Set 6 | biloela
# Processing Record 27 of Set 6 | puerto santa
# Processing Record 28 of Set 6 | nahiyat ash shinafiyah
# Processing Record 29 of Set 6 | allapalli
# Processing Record 30 of Set 6 | chonchi
# Processing Record 31 of Set 6 | xai-xai
# Processing Record 32 of Set 6 | ijevan
# Processing Record 33 of Set 6 | gur'yevsk
# Processing Record 34 of Set 6 | enewetak
# Processing Record 35 of Set 6 | antofagasta
# Processing Record 36 of Set 6 | saksaul'skiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | nemuro
# Processing Record 38 of Set 6 | parauapebas
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | harstad
# Processing Record 41 of Set 6 | pangody
# Processing Record 42 of Set 6 | heihe
# Processing Record 43 of Set 6 | kodar
# Processing Record 44 of Set 6 | mil'kovo
# Processing Record 45 of Set 6 | fort bragg
# Processing Record 46 of Set 6 | ubinskoye
# Processing Record 47 of Set 6 | myrina
# Processing Record 48 of Set 6 | egilsstadir
# Processing Record 49 of Set 6 | cidade velha
# Processing Record 0 of Set 7 | turmalina
# Processing Record 1 of Set 7 | pipar
# Processing Record 2 of Set 7 | axim
# Processing Record 3 of Set 7 | hashtpar
# Processing Record 4 of Set 7 | tiflet
# Processing Record 5 of Set 7 | brookings
# Processing Record 6 of Set 7 | amga
# Processing Record 7 of Set 7 | puerto carreno
# Processing Record 8 of Set 7 | guiuan
# Processing Record 9 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 7 | kingston
# Processing Record 11 of Set 7 | porto novo
# Processing Record 12 of Set 7 | kharp
# Processing Record 13 of Set 7 | fethiye
# Processing Record 14 of Set 7 | timmins
# Processing Record 15 of Set 7 | mako
# Processing Record 16 of Set 7 | sinop
# Processing Record 17 of Set 7 | iqaluit
# Processing Record 18 of Set 7 | bhainsdehi
# Processing Record 19 of Set 7 | villa presidente frei, nunoa, santiago, chile
# City not found. Skipping...
# Processing Record 20 of Set 7 | tazovsky
# Processing Record 21 of Set 7 | ngereklmadel
# Processing Record 22 of Set 7 | enschede
# Processing Record 23 of Set 7 | sisimiut
# Processing Record 24 of Set 7 | prince rupert
# Processing Record 25 of Set 7 | avarua
# Processing Record 26 of Set 7 | boali
# Processing Record 27 of Set 7 | taro
# Processing Record 28 of Set 7 | ponta delgada
# Processing Record 29 of Set 7 | hami
# Processing Record 30 of Set 7 | reggane
# Processing Record 31 of Set 7 | mahibadhoo
# Processing Record 32 of Set 7 | gabane
# Processing Record 33 of Set 7 | kirkland lake
# Processing Record 34 of Set 7 | walvis bay
# Processing Record 35 of Set 7 | aral
# Processing Record 36 of Set 7 | kerikeri
# Processing Record 37 of Set 7 | custodia
# Processing Record 38 of Set 7 | vadso
# Processing Record 39 of Set 7 | shiguai
# Processing Record 40 of Set 7 | bullhead city
# Processing Record 41 of Set 7 | altai
# Processing Record 42 of Set 7 | sorong
# Processing Record 43 of Set 7 | nizhnyaya tavda
# Processing Record 44 of Set 7 | villa gesell
# Processing Record 45 of Set 7 | belozersk
# Processing Record 46 of Set 7 | urangan
# Processing Record 47 of Set 7 | ipsala
# Processing Record 48 of Set 7 | mar del plata
# Processing Record 49 of Set 7 | severnoye
# Processing Record 0 of Set 8 | kapa'a
# Processing Record 1 of Set 8 | berdigestyakh
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | charters towers
# Processing Record 4 of Set 8 | inirida
# Processing Record 5 of Set 8 | kuanda
# Processing Record 6 of Set 8 | cat ba
# City not found. Skipping...
# Processing Record 7 of Set 8 | broome
# Processing Record 8 of Set 8 | baragua
# Processing Record 9 of Set 8 | giarmata
# Processing Record 10 of Set 8 | gueltat zemmour
# City not found. Skipping...
# Processing Record 11 of Set 8 | queenstown
# Processing Record 12 of Set 8 | karayazi
# Processing Record 13 of Set 8 | tofol
# Processing Record 14 of Set 8 | sinabang
# Processing Record 15 of Set 8 | kangding
# Processing Record 16 of Set 8 | kununurra
# Processing Record 17 of Set 8 | koupela
# Processing Record 18 of Set 8 | maceio
# Processing Record 19 of Set 8 | sarkand
# Processing Record 20 of Set 8 | colonia
# Processing Record 21 of Set 8 | namtsy
# Processing Record 22 of Set 8 | saint-philippe
# Processing Record 23 of Set 8 | arraial do cabo
# Processing Record 24 of Set 8 | luderitz
# Processing Record 25 of Set 8 | mili
# Processing Record 26 of Set 8 | tshabong
# Processing Record 27 of Set 8 | city of balikpapan
# Processing Record 28 of Set 8 | la passe
# Processing Record 29 of Set 8 | mana
# Processing Record 30 of Set 8 | ketchikan
# Processing Record 31 of Set 8 | nuuk
# Processing Record 32 of Set 8 | mugumu
# Processing Record 33 of Set 8 | labuan
# Processing Record 34 of Set 8 | rumbek
# Processing Record 35 of Set 8 | conduaga
# Processing Record 36 of Set 8 | terenozek
# Processing Record 37 of Set 8 | carnarvon
# Processing Record 38 of Set 8 | khabarovsk
# Processing Record 39 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 40 of Set 8 | port alfred
# Processing Record 41 of Set 8 | red bluff
# Processing Record 42 of Set 8 | nova sintra
# Processing Record 43 of Set 8 | muli
# Processing Record 44 of Set 8 | crucecita
# Processing Record 45 of Set 8 | trairi
# Processing Record 46 of Set 8 | toliara
# Processing Record 47 of Set 8 | kabansk
# Processing Record 48 of Set 8 | sicuani
# Processing Record 49 of Set 8 | pangkalan brandan
# Processing Record 0 of Set 9 | genhe
# Processing Record 1 of Set 9 | copala
# Processing Record 2 of Set 9 | erenhot
# Processing Record 3 of Set 9 | port augusta
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | kujang-up
# Processing Record 6 of Set 9 | nadym
# Processing Record 7 of Set 9 | indi
# Processing Record 8 of Set 9 | galle
# Processing Record 9 of Set 9 | basco
# Processing Record 10 of Set 9 | lisala
# Processing Record 11 of Set 9 | aki
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | zeya
# Processing Record 14 of Set 9 | mukalla
# Processing Record 15 of Set 9 | east end
# Processing Record 16 of Set 9 | novodvinsk
# Processing Record 17 of Set 9 | vuktyl
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | abha
# Processing Record 20 of Set 9 | romorantin-lanthenay
# Processing Record 21 of Set 9 | manta
# Processing Record 22 of Set 9 | sumenep
# Processing Record 23 of Set 9 | olyokminsk
# Processing Record 24 of Set 9 | chegdomyn
# Processing Record 25 of Set 9 | manakara
# Processing Record 26 of Set 9 | pangani
# Processing Record 27 of Set 9 | ntcheu
# Processing Record 28 of Set 9 | fortaleza
# Processing Record 29 of Set 9 | mitu
# Processing Record 30 of Set 9 | nevinnomyssk
# Processing Record 31 of Set 9 | cedeira
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | kidal
# Processing Record 34 of Set 9 | muisne
# Processing Record 35 of Set 9 | la'ie
# Processing Record 36 of Set 9 | khamis mushait
# Processing Record 37 of Set 9 | bayanhongor
# Processing Record 38 of Set 9 | otaru
# Processing Record 39 of Set 9 | hammerfest
# Processing Record 40 of Set 9 | larose
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | ola
# Processing Record 43 of Set 9 | preston
# Processing Record 44 of Set 9 | santa cruz
# Processing Record 45 of Set 9 | yaren
# Processing Record 46 of Set 9 | ocean shores
# Processing Record 47 of Set 9 | rotorua
# Processing Record 48 of Set 9 | delson
# Processing Record 49 of Set 9 | kayangel
# Processing Record 0 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 1 of Set 10 | mammoth lakes
# Processing Record 2 of Set 10 | balakirevo
# Processing Record 3 of Set 10 | porto velho
# Processing Record 4 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 5 of Set 10 | barberton
# Processing Record 6 of Set 10 | al musayyib
# Processing Record 7 of Set 10 | calvinia
# Processing Record 8 of Set 10 | palmer
# Processing Record 9 of Set 10 | coahuayana de hidalgo
# Processing Record 10 of Set 10 | pisco
# Processing Record 11 of Set 10 | akouda
# Processing Record 12 of Set 10 | hanchuan
# Processing Record 13 of Set 10 | wanxian
# Processing Record 14 of Set 10 | jericho
# Processing Record 15 of Set 10 | omarska
# Processing Record 16 of Set 10 | menongue
# Processing Record 17 of Set 10 | castillos
# Processing Record 18 of Set 10 | coquimbo
# Processing Record 19 of Set 10 | glace bay
# Processing Record 20 of Set 10 | nogliki
# Processing Record 21 of Set 10 | bontang
# Processing Record 22 of Set 10 | sirjan
# Processing Record 23 of Set 10 | det udom
# Processing Record 24 of Set 10 | el nido
# Processing Record 25 of Set 10 | lompoc
# Processing Record 26 of Set 10 | calama
# Processing Record 27 of Set 10 | solnechnyy
# Processing Record 28 of Set 10 | korla
# Processing Record 29 of Set 10 | knurow
# Processing Record 30 of Set 10 | coxcatlan
# Processing Record 31 of Set 10 | trevelin
# Processing Record 32 of Set 10 | kentau
# Processing Record 33 of Set 10 | fale old settlement
# Processing Record 34 of Set 10 | alcantara
# Processing Record 35 of Set 10 | acarau
# Processing Record 36 of Set 10 | kawthoung
# City not found. Skipping...
# Processing Record 37 of Set 10 | bikenibeu village
# Processing Record 38 of Set 10 | verkhniy baskunchak
# Processing Record 39 of Set 10 | lockwood
# Processing Record 40 of Set 10 | alofi
# Processing Record 41 of Set 10 | kailua-kona
# Processing Record 42 of Set 10 | sao gabriel da cachoeira
# Processing Record 43 of Set 10 | carauari
# Processing Record 44 of Set 10 | chui
# Processing Record 45 of Set 10 | mek'ele
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | pitoa
# Processing Record 48 of Set 10 | inhambane
# Processing Record 49 of Set 10 | bandirma
# Processing Record 0 of Set 11 | papao
# Processing Record 1 of Set 11 | ermoupolis
# Processing Record 2 of Set 11 | arawa
# Processing Record 3 of Set 11 | nyurba
# Processing Record 4 of Set 11 | kilindoni
# Processing Record 5 of Set 11 | sanaa
# Processing Record 6 of Set 11 | longquan
# Processing Record 7 of Set 11 | xichang
# Processing Record 8 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 11 | nagqu
# Processing Record 10 of Set 11 | carupano
# Processing Record 11 of Set 11 | saint-louis
# Processing Record 12 of Set 11 | severo-yeniseyskiy
# Processing Record 13 of Set 11 | grand falls-windsor
# Processing Record 14 of Set 11 | impfondo
# Processing Record 15 of Set 11 | wellington
# Processing Record 16 of Set 11 | lonar
# Processing Record 17 of Set 11 | khovd
# Processing Record 18 of Set 11 | post
# Processing Record 19 of Set 11 | camocim
# Processing Record 20 of Set 11 | tercan
# Processing Record 21 of Set 11 | cartagena del chaira
# Processing Record 22 of Set 11 | maraba
# Processing Record 23 of Set 11 | armacao de buzios
# Processing Record 24 of Set 11 | cuencame de ceniceros
# Processing Record 25 of Set 11 | tamanrasset
# Processing Record 26 of Set 11 | machico
# Processing Record 27 of Set 11 | myeik
# Processing Record 28 of Set 11 | colby
# Processing Record 29 of Set 11 | nizhneangarsk
# Processing Record 30 of Set 11 | swan hill
# Processing Record 31 of Set 11 | cestos city
# Processing Record 32 of Set 11 | saint-junien
# Processing Record 33 of Set 11 | daru
# Processing Record 34 of Set 11 | angaur state
# Processing Record 35 of Set 11 | westport
# Processing Record 36 of Set 11 | forster
# Processing Record 37 of Set 11 | cockburn town
# Processing Record 38 of Set 11 | chemax
# Processing Record 39 of Set 11 | ciudad madero
# Processing Record 40 of Set 11 | houlton
# Processing Record 41 of Set 11 | pamandzi
# Processing Record 42 of Set 11 | soata
# Processing Record 43 of Set 11 | puerto deseado
# Processing Record 44 of Set 11 | hasaki
# Processing Record 45 of Set 11 | ust'-uda
# Processing Record 46 of Set 11 | praia da vitoria
# Processing Record 47 of Set 11 | nizhneudinsk
# Processing Record 48 of Set 11 | hamamatsu
# Processing Record 49 of Set 11 | ust'-ilimsk
# Processing Record 0 of Set 12 | mumford
# Processing Record 1 of Set 12 | turpan
# Processing Record 2 of Set 12 | bulungu
# Processing Record 3 of Set 12 | mount darwin
# Processing Record 4 of Set 12 | sol'tsy
# Processing Record 5 of Set 12 | quellon
# Processing Record 6 of Set 12 | ulsteinvik
# Processing Record 7 of Set 12 | enriquillo
# Processing Record 8 of Set 12 | naryn
# Processing Record 9 of Set 12 | homer
# Processing Record 10 of Set 12 | howrah
# Processing Record 11 of Set 12 | labrador city
# Processing Record 12 of Set 12 | chapaev
# Processing Record 13 of Set 12 | madalena
# Processing Record 14 of Set 12 | vershino-darasunskiy
# Processing Record 15 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 12 | aldan
# Processing Record 17 of Set 12 | lethem
# Processing Record 18 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 19 of Set 12 | ulaangom
# Processing Record 20 of Set 12 | nieuw amsterdam
# Processing Record 21 of Set 12 | usinsk
# Processing Record 22 of Set 12 | rawlins
# Processing Record 23 of Set 12 | puerto baquerizo moreno
# Processing Record 24 of Set 12 | ceerigaabo
# Processing Record 25 of Set 12 | mahabe
# City not found. Skipping...
# Processing Record 26 of Set 12 | valle de la pascua
# Processing Record 27 of Set 12 | minas de marcona
# Processing Record 28 of Set 12 | mogok
# Processing Record 29 of Set 12 | lubao
# Processing Record 30 of Set 12 | bratsk
# Processing Record 31 of Set 12 | arauquita
# Processing Record 32 of Set 12 | karsava
# Processing Record 33 of Set 12 | miri
# Processing Record 34 of Set 12 | urengoy
# Processing Record 35 of Set 12 | teknaf
# Processing Record 36 of Set 12 | ilhabela
# Processing Record 37 of Set 12 | al bawiti
# Processing Record 38 of Set 12 | kurgan
# Processing Record 39 of Set 12 | santo domingo
# Processing Record 40 of Set 12 | tommot
# Processing Record 41 of Set 12 | noosa heads
# Processing Record 42 of Set 12 | fannuj
# City not found. Skipping...
# Processing Record 43 of Set 12 | paradip garh
# Processing Record 44 of Set 12 | maymana
# Processing Record 45 of Set 12 | malacca
# Processing Record 46 of Set 12 | souillac
# Processing Record 47 of Set 12 | muborak
# Processing Record 48 of Set 12 | kolonia town
# Processing Record 49 of Set 12 | yuzhno-kurilsk
# Processing Record 0 of Set 13 | prado
# Processing Record 1 of Set 13 | bonthe
# Processing Record 2 of Set 13 | tinajo
# Processing Record 3 of Set 13 | vanino
# Processing Record 4 of Set 13 | businga
# Processing Record 5 of Set 13 | manismata
# Processing Record 6 of Set 13 | myanaung
# Processing Record 7 of Set 13 | satte
# Processing Record 8 of Set 13 | lamu
# Processing Record 9 of Set 13 | santa elena de uairen
# Processing Record 10 of Set 13 | porvoo
# Processing Record 11 of Set 13 | childress
# Processing Record 12 of Set 13 | dryden
# Processing Record 13 of Set 13 | suai
# City not found. Skipping...
# Processing Record 14 of Set 13 | camapua
# Processing Record 15 of Set 13 | polyarnyy
# Processing Record 16 of Set 13 | amahai
# Processing Record 17 of Set 13 | hirara
# Processing Record 18 of Set 13 | izazi
# Processing Record 19 of Set 13 | akhmet'a
# Processing Record 20 of Set 13 | la junta
# Processing Record 21 of Set 13 | staraya mayna
# Processing Record 22 of Set 13 | birao
# Processing Record 23 of Set 13 | tarfaya
# Processing Record 24 of Set 13 | harar
# Processing Record 25 of Set 13 | ancud
# Processing Record 26 of Set 13 | can picafort
# City not found. Skipping...
# Processing Record 27 of Set 13 | kapsowar
# City not found. Skipping...
# Processing Record 28 of Set 13 | viedma
# Processing Record 29 of Set 13 | hillvue
# Processing Record 30 of Set 13 | as sulayyil
# Processing Record 31 of Set 13 | extrema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          605
# Lat           605
# Lng           605
# Max Temp      605
# Humidity      605
# Cloudiness    605
# Wind Speed    605
# Country       605
# Date          605
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       grytviken -54.2811  -36.5092      3.97        95         100
# 1  guerrero negro  27.9769 -114.0611     21.11        51          22
# 2            sile  41.1754   29.6133      5.32        53          83
# 3          kodiak  57.7900 -152.4072      3.73        93          75
# 4         nguigmi  14.2495   13.1092     27.21        27          39
#
#    Wind Speed Country        Date
# 0        3.90      GS  1701041119
# 1        5.07      MX  1701041119
# 2        1.79      TR  1701041119
# 3        2.06      US  1701041119
# 4        4.93      NE  1701041120

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             grytviken -54.2811  -36.5092      3.97        95         100
# 1        guerrero negro  27.9769 -114.0611     21.11        51          22
# 2                  sile  41.1754   29.6133      5.32        53          83
# 3                kodiak  57.7900 -152.4072      3.73        93          75
# 4               nguigmi  14.2495   13.1092     27.21        27          39
#
#          Wind Speed Country        Date
# City_ID
# 0              3.90      GS  1701041119
# 1              5.07      MX  1701041119
# 2              1.79      TR  1701041119
# 3              2.06      US  1701041119
# 4              4.93      NE  1701041120

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_latitudes = [city['Lat'] for city in city_data]
city_temperatures = [city['Max Temp'] for city in city_data]

# Incorporate the other graph properties
plt.scatter(city_latitudes, city_temperatures)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2023-11-26)")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
city_humidity = [city['Humidity'] for city in city_data]

# Incorporate the other graph properties
plt.scatter(city_latitudes, city_humidity)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Max Latitude vs. Humidity (2023-11-26)")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_cloudiness = [city['Cloudiness'] for city in city_data]

# Incorporate the other graph properties
plt.scatter(city_latitudes, city_cloudiness)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Max Latitude vs. Cloudiness (2023-11-26)")
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_cloudiness = [city['Wind Speed'] for city in city_data]

# Incorporate the other graph properties
plt.scatter(city_latitudes, city_cloudiness)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs. Windspeed (2023-11-26)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create scatter plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-", label=line_eq)

    # Label plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Print r-squared value
    print(f"The r-squared is: {rvalue**2}")

    # Show plot
    plt.legend()
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
city_data_df['Lat'] = city_data_df['Lat'].astype(float)
city_data_df['Lng'] = city_data_df['Lng'].astype(float)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        guerrero negro  27.9769 -114.0611     21.11        51          22
# 2                  sile  41.1754   29.6133      5.32        53          83
# 3                kodiak  57.7900 -152.4072      3.73        93          75
# 4               nguigmi  14.2495   13.1092     27.21        27          39
# 8              jinchang  38.4953  102.1739      0.92        44          35
#
#          Wind Speed Country        Date
# City_ID
# 1              5.07      MX  1701041119
# 2              1.79      TR  1701041119
# 3              2.06      US  1701041119
# 4              4.93      NE  1701041120
# 8              2.86      CN  1701041120

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                grytviken -54.2811  -36.5092      3.97        95         100
# 5        port-aux-francais -49.3500   70.2167      3.51        75         100
# 6                papatowai -46.5619  169.4708     14.07        70          99
# 7            port mathurin -19.6833   63.4167     24.70        74          56
# 9                    leava -14.3000 -178.1667     28.86        77          86
#
#          Wind Speed Country        Date
# City_ID
# 0              3.90      GS  1701041119
# 5              7.04      TF  1701041120
# 6              2.14      NZ  1701041120
# 7              7.61      MU  1701041120
# 9              5.98      WF  1701041121

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], "Latitude","Max Temp")
# Out:
# The r-squared is: 0.7483772692161368

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], "Latitude","Max Temp")
# Out:
# The r-squared is: 0.45384537805947356

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong correlation to the temperature of a city as it gets closer to the equator. The northern hemisphere has a higher r-squared value of 0.748 vs 0.453 meaning that the correlation is stronger on the northern hemisphere than it is at the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.05457992771746187

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.08650068058542694

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation to the humidity of a city as it gets closer to the equator. The southern hemisphere has a higher r-squared value of 0.054 vs 0.086 meaning that the correlation is stronger on the southern hemisphere than it is at the northern hemisphere, however the correlation is very weak.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.017817957107233714

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.01176144531187704

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation to the cloudiness of a city as it gets closer to the equator. The northern hemisphere has a higher r-squared value of 0.017 vs 0.011 meaning that the correlation is stronger on the northern hemisphere than it is at the southern hemisphere, however the correlation is very weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.005118042504658593

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], "Latitude","Humidity")
# Out:
# The r-squared is: 0.05026817892359211

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation to the Wind Speed of a city as it gets closer to the equator. The northern hemisphere has a higher r-squared value of 0.005 vs 0.011 meaning that the correlation is stronger on the northern hemisphere than it is at the southern hemisphere, however the correlation is very weak.
